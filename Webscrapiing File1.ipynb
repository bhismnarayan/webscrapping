# %%
import requests
from bs4 import BeautifulSoup

# %%
# Get method toenter the Url:

r = requests.get("https://mashable.com/2017/02/20/microsoft-satya-nadella-artificial-intelligence-focus/#ChdaO3XtOiqP")
c = r.content
soup = BeautifulSoup(c,"html.parser")

all = soup.find("h1",{"class":"title"}).text

# %%
all
# Out:
# "Microsoft CEO says artificial intelligence is the 'ultimate breakthrough'"

# %%
Img_url = soup.find("figure",{"class":"article-image"})

# %%
Img_url
# Out:
# <figure class="article-image"><img alt="" class="microcontent" data-fragment="lead-image" data-image="https://i.amz.mshcdn.com/WU1xwJW729e5-bRTWKiKGw6CEYQ=/950x534/filters:quality(90)/https%3A%2F%2Fblueprint-api-production.s3.amazonaws.com%2Fuploads%2Fcard%2Fimage%2F391067%2Ff283e5a7-47c7-4ec2-891f-575481b57751.jpg" data-micro="1" data-url="null" src="https://i.amz.mshcdn.com/WU1xwJW729e5-bRTWKiKGw6CEYQ=/950x534/filters:quality(90)/https%3A%2F%2Fblueprint-api-production.s3.amazonaws.com%2Fuploads%2Fcard%2Fimage%2F391067%2Ff283e5a7-47c7-4ec2-891f-575481b57751.jpg"/><div class="image-credit">Image:  AP/REX/Shutterstock</div></figure>

# %%
import os

import requests
from lxml import html


class ImageScraper:
    def __init__(self, url, download_path):
        self.url = url
        self.download_path = download_path

        self.session = requests.Session()

    def scrape_images(self):
        response = self.session.get(self.url).text

        tree = html.fromstring(response)
        for movie in tree.xpath('//div[@class="mv"]'):
            title = movie.findtext('.//h3/a')

            image_url = "https:" + movie.xpath('.//img/@src')[0]
            image_name = image_url.split('/')[-1]

            self.save_image(title, image_name, image_url)

    def save_image(self, movie_name, file_name, item_link):
        response = self.session.get(item_link, stream=True)

        if response.status_code == 200:
            with open(os.path.join(self.download_path, file_name), 'wb') as image_file:
                for chunk in response.iter_content(1024):
                    image_file.write(chunk)

        print(movie_name, file_name)


if __name__ == '__main__':
    scraper = ImageScraper(url="https://www.yify-torrent.org/search/1080p/",
                           download_path=r"C:\Users\Nikhil")
    scraper.scrape_images()

# %%
scraper = ImageScraper(url="https://www.yify-torrent.org/search/1080p/",
                           download_path=r"C:\Users\Nikhil")

# %%
print(scraper)

# %%
import sys
from PyQt5.QtWidgets import QApplication
from PyQt5.QtCore import QUrl 
from PyQt5.QtWebEngineWidgets import QWebEnginePage
import bs4 as bs
import requests

class Client(QWebEnginePage):
    
    def __init__(self, url):
        self.app = QApplication(sys.argv)
        QWebEnginePage.__init__(self)
        self.html = ''
        self.loadFinished.connect(self._on_load_finished)
        self.load(QUrl(url))
        self.app.exec_()
        
        
    def on_page_load(self):
        self.html = self.toHtml(self.Callable)
        print('Load finished')
        
        
    def Callable(self, html_str):
        
        self.html = html_str
        self.app.quit()
        

        
                
url = "https://mashable.com/2017/02/20/microsoft-satya-nadella-artificial-intelligence-focus/"
p = requests.get(url).text
#source = client_response.mainFrame().toHtml()
soup = bs.BeautifulSoup(p, 'html.parser')
js_test = soup.find('p', class_='jstest')
try:
    
    print(js_test.text)
    
except:
    pass

# %%
p
# Out:
# '<!DOCTYPE html>\n<html data-env=\'production\' lang=\'en\' xml:lang=\'en\'>\n<head>\n<script type="text/javascript">window.NREUM||(NREUM={});NREUM.info={"beacon":"bam.nr-data.net","errorBeacon":"bam.nr-data.net","licenseKey":"faaaef6476","applicationID":"1135420","transactionName":"cAkNR0ENXQpXF0tJDUASEBxACl4R","queueTime":0,"applicationTime":89,"agent":""}</script>\n<script type="text/javascript">(window.NREUM||(NREUM={})).loader_config={xpid:"VwYHUF9ACQIDUVVQBw=="};window.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var o=e[n]={exports:{}};t[n][0].call(o.exports,function(e){var o=t[n][1][e];return r(o||e)},o,o.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<n.length;o++)r(n[o]);return r}({1:[function(t,e,n){function r(t){try{s.console&&console.log(t)}catch(e){}}var o,i=t("ee"),a=t(21),s={};try{o=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(s.console=!0,o.indexOf("
# ...

# %%
#getting text document from web, below function based from 3
from bs4 import BeautifulSoup
from urllib.request import urlopen
from pylab import *
 
def get_only_text(url):
 """ 
  return the title and the text of the article
  at the specified url
 """
 page = urlopen(url)
 soup = BeautifulSoup(page, "lxml")
 text = ' '.join(map(lambda p: p.text, soup.find_all('p')))
 return soup.title.text, text    
 
  
print ('Summary:')
print (summarize(text, ratio=0.01))
 
print ('\nKeywords:')
print (keywords(text, ratio=0.01))
 
url="https://en.wikipedia.org/wiki/Deep_learning"
text = get_only_text(url)
 
print ('Summary:')   
print (summarize(str(text), ratio=0.01))
 
print ('\nKeywords:')
 
# higher ratio => more keywords
print (keywords(str(text), ratio=0.01))
# Out:
# Summary:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-c0bf7a2c2357> in <module>()
#      16
#      17 print ('Summary:')
# ---> 18 print (summarize(text, ratio=0.01))
#      19
#      20 print ('\nKeywords:')
#
# NameError: name 'summarize' is not defined

# %%
import html2text
import requests
#Make the proxy settings, if your access is through a proxy server

url = "https://mashable.com/2017/02/20/microsoft-satya-nadella-artificial-intelligence-focus/"
res = requests.get(url, timeout=5.0 )
html = res.text
# extract the text from the html version
text = html2text.html2text(html)
print(text)
# Out:
# ![](https://zdbb.net/l/z0WVjCBSEeGLoxIxOQVEwQ)
#
# # Mashable
#
# We're using cookies to improve your experience. [Click Here to find out
# more.](/cookie-policy/)
#
#   *   * [Mashable ![Header logo.v2.in 4d5f1a092c48e9233425f15c44f25a7c0cbed1bedbd8335160519124df085d70](https://a.amz.mshcdn.com/assets/header_logo.v2.in-4d5f1a092c48e9233425f15c44f25a7c0cbed1bedbd8335160519124df085d70.png)![Header logo.v2.in.dark 6b9cbc5f71f93f6822d795def6fd049efa1fd58bd0ec75e1b05a734c28972a35](https://a.amz.mshcdn.com/assets/header_logo.v2.in.dark-6b9cbc5f71f93f6822d795def6fd049efa1fd58bd0ec75e1b05a734c28972a35.png)](/)
#
# [Mashable](?geo=US&utm_cid=mash-prod-nav-geo) [Mashable
# Asia](?geo=AS&utm_cid=mash-prod-nav-geo) [Mashable
# Australia](?geo=AU&utm_cid=mash-prod-nav-geo) [Mashable
# UK](?geo=GB&utm_cid=mash-prod-nav-geo)
#
#   * [Sign in](/login/)
#   * [ ](/follow-mashable/)
#
#     * Like
#     * [ Follow ](https://twitter.com/mashable)
# ...

# %%
import lassie
import pprint
url="https://mashable.com/2017/02/20/microsoft-satya-nadella-artificial-intelligence-focus/"
x = lassie.fetch(url, all_images=True)

pprint.pprint(x)
#len(x)
# Out:
# {'description': 'Nothing beats the understanding of natural language.',
#  'images': [{'height': 627,
#              'src': 'https://i.amz.mshcdn.com/mMJauqHeOostwvPvVZPYV9VRsYA=/1200x627/2017%2F02%2F20%2F89%2F569934fa43ad4108a7578e73129256c9.fca28.jpg',
#              'width': 1200},
#             {'src': 'https://i.amz.mshcdn.com/Y1hX8QKfQSYpyEuCRMgLhAXPMQo=/1200x630/2017%2F02%2F20%2Fdc%2F8150dd1cca63429da9001a36d7b3b313.fca28.jpg',
#              'type': 'og:image'},
#             {'height': 360,
#              'src': 'https://i.amz.mshcdn.com/uG9nIIRxr2Z9rYorkxNJgL5sOj4=/640x360/https%3A%2F%2Fblueprint-api-production.s3.amazonaws.com%2Fuploads%2Fstory%2Fthumbnail%2F37329%2F8150dd1c-ca63-429d-a900-1a36d7b3b313.jpg',
#              'type': 'twitter:image',
#              'width': 640},
#             {'src': 'https://mashable.com/favicon-32x32.png?v=m2Pmw8zNwl',
#              'type': 'favicon'},
#             {'src': 'https://mashable.com/android-chrome-192x192.png?v=m2Pmw8zNwl',
# ...

# %%
import nltk
nltk.download('punkt')
from newspaper import Article 

url = "http://mashable.com/2017/02/20/microsoft-satya-nadella-artificial-intelligence-focus/"
 
article = Article(url)
 
#1 . Download the article
article.download()
 
#2. Parse the article
article.parse()
print(" ")
print(" ")

#3. The URL of the Major Image
print("Major Image in the article:")
print(article.top_image)
print(" ")

 
#4. Fetch Author Name(s)
print(article.authors)
print(" ")
print(article.title)
print(" ")
print(article.url)
print(" ")
print(article.text)
print(" ")
print(" ")

print("Duration to read full text")
print((len(article.text))/500)
print(" ")
print("Duration to read summarized text")
print((len(article.summary))/500)
#print(article.throw_if_not_downloaded_verbose)
print(" ")
print(" ")

#print(article.top_node)
 
#4. Fetch Publication Date
print("Article Publication Date:")
print(article.publish_date)
print(" ")

 
#6. Natural Language Processing on Article to fetch Keywords
article.nlp()
print ("Keywords in the article")
print(article.keywords) 
print(" ")
 
#7. Generate Summary of the article
print("Article Summary")
print(article.summary)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Nikhil\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
#
#
# Major Image in the article:
# https://i.amz.mshcdn.com/Y1hX8QKfQSYpyEuCRMgLhAXPMQo=/1200x630/2017%2F02%2F20%2Fdc%2F8150dd1cca63429da9001a36d7b3b313.fca28.jpg
#
# ['Sohini Mitter']
#
# Microsoft CEO says artificial intelligence is the 'ultimate breakthrough'
#
# http://mashable.com/2017/02/20/microsoft-satya-nadella-artificial-intelligence-focus/
#
# Microsoft CEO Satya Nadella spoke at a public event in India on Monday, stressing upon the immense potential of artificial intelligence (AI), calling it the "ultimate breakthrough" in technology.
#
# "Because for all the advances in computer interface, there is nothing to beat language [the ability to do human-level speech recognition]," he said during a fireside chat with Nandan Nilekani — India's premier technocrat and the brain behind the Aadhaar identification system.
#
# ...

# %%
import Goose 

url = "https://mashable.com/2017/02/20/microsoft-satya-nadella-artificial-intelligence-focus/"
g = Goose()
article = g.extract(url=url)
print("Title:")
print(article.title)
print("Meta Description")
print(article.meta_description)
 
print("First n characters of the cleaned text")
print(article.cleaned_text[:200])
print ("URL of Main image")
print(article.top_image.src)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-43-c33c131ca986> in <module>()
# ----> 1 import Goose
#       2
#       3 url = "https://mashable.com/2017/02/20/microsoft-satya-nadella-artificial-intelligence-focus/"
#       4 g = Goose()
#       5 article = g.extract(url=url)
#
# ModuleNotFoundError: No module named 'Goose'

# %%
import goose-extractor
# Out:
#   File "<ipython-input-40-266422d7c59d>", line 1
#     import goose-extractor
#                 ^
# SyntaxError: invalid syntax
